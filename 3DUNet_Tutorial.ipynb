# %%
# !git clone https://github.com/chi-sq/3DUNet

# %%
# !cd 3DUNet

# %%
# !pip3 install -r requirements.txt

# %% [markdown]
# 下载数据

# %%
# !python3 -m starter_code.get_imaging

# %% [markdown]
# 新建目录用于存放权重文件和实验结果

# %%
# !mkdir checkpoints index

# %% [markdown]
# 划分训练集和测试集，如下图。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 接下来就可以开始训练了。

# %%
# !python train.py
# Out:
# running on cuda
# start to train
# 100% 95/95 [11:18<00:00,  7.14s/it]
# epoch1 done!!!
# start to validation
# 100% 20/20 [01:48<00:00,  5.43s/it, tk_dice=0.196, tu_dice=0.0112]
# validation ending--
# tk_dice = 0.196249166488982,tu_dice = 0.011244550900613671
# => Saving checkpoint => ./checkpoints/weights_croped_mixed_C_D_loss_new_BN_.pth.tar
#  15% 14/95 [01:31<08:32,  6.33s/it]

# %% [markdown]
# 训练完之后，就可以对于个体进行预测了，这里预测与后处理合并，输出直接是**nii.gz**格式的文件。
#
# 注意在**config**文件中设置**'LOAD_MODEL = True'**
#
# 如果你不想进行个体的预测，你可以运行**val.py**来查看在验证集的效果

# %%
# !python postporcess.py
